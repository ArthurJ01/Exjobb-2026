# %%
import pandas as pd

# load data
df = pd.read_csv("Dataset/clustering_samples.csv")
df = df[["start_timestamp", "end_timestamp", "cluster"]]

# sort by start time
df = df.sort_values(by="start_timestamp")

df.to_excel("Clustering/clustering_samples_with_clusters.xlsx", index=False)

df = df[["start_timestamp", "end_timestamp"]]

df.to_excel("Clustering/clustering_samples.xlsx", index=False)
